# %% [markdown]
# # Lab 10 Dynamical Friction
#
# Starting from the Homework 7 Solutions, add Dynamical Friction to better match the simulation data.

# %%
# import necessary modules
# numpy provides powerful multi-dimensional 
#arrays to hold and manipulate data
import numpy as np
# matplotlib provides powerful functions for plotting figures
import matplotlib.pyplot as plt
# astropy provides unit system and constants 
#for astronomical calculations
import astropy.units as u
import astropy.constants as const
# import Latex module so we can display the results with symbols
from IPython.display import Latex

# import the CenterOfMass to determine the COM pos/vel of M33
from CenterOfMass2 import CenterOfMass
# import the GalaxyMass to determine the 
#mass of M31 for each component
from GalaxyMass import ComponentMass

# %% [markdown]
# # M33AnalyticOrbit - Version 2
#
# 1. Add a new variable to the initializer for the class,  `self.M33halo`,  that defines M33's halo mass.
#
# 2. Add a new varaible to the initialization of the class, `self.Vc`, the circular speed at large radii from M31. Let's assume this is flat at $V_c$ = 200 km/s in the M31 halo outskirts.  or 230 from Homework 5
#
# 3. Add a function called `DynamicalFriction` that takes as inputs (Msat,r,v), and computes the acceleration, assuming an isothermal sphere profile for the dark matter halo of M31.
#
# $ {\bf a} =  -0.428 \frac{GM_{\rm sat} \rm{ln}(\Lambda)}{r^2} \frac{\bf v}{v} $
#
# Where the ${\rm ln}(\Lambda)$ is the Coulomb logairthm
#
# $\Lambda = \frac{bmax}{bmin} $
#
# $bmax$ = the current separation between M31 and M33 and
#
# $bmin = \frac{GM_{sat}}{V_c^2}$
#
# 4. Include this function in M33Accel.  Note that it will require a new input, v (velocity vector). This must be accounted for also when M33Accel is called in LeapFrog
#
# 5. If the orbit doesn't match well. Add a fudge factor (`self.fudge`) that is some fraction of 1 to decrease the strength of the dynamical friction term.
#
# 6. What other reasons might there be for why the orbits don't match?

# %%
class M33AnalyticOrbit:
    '''Class that integrates the orbit of 
    M33 based on the analytic form of M31's potential'''
    
    
    def __init__(self, filename):
        '''
        This class uses leapfrog integration 
        to calculate the orbit of M33 around M31,
        using the analytic potentials for each 
        of M31's components.

        PARAMETERS
        ----------
        filename : `str`
            Name of the file in which to store the orbit
        '''    
        
        # get the gravitational constant (the value is 4.498502151575286e-06)
        self.G = const.G.to(u.kpc**3/u.Msun/u.Gyr**2).value
        
        # store the output file name
        self.filename = filename
        
        # get the COM position and velocity of each galaxy using disk particles
        
        # COM object 
        com_M31 = CenterOfMass('M31_000.txt', 2) # COM object for M31
        com_M33 = CenterOfMass('M33_000.txt', 2) # COM object for M33
        # COM Pos and Velocity for M31
        com_p_M31 = com_M31.COM_P(volDec=2, delta=0.1)
        com_v_M31 = com_M31.COM_V(com_p_M31[0], com_p_M31[1], com_p_M31[2])
        # COM Pos and Velocity for for M33
        com_p_M33 = com_M33.COM_P(volDec=4, delta=0.1)
        com_v_M33 = com_M33.COM_V(com_p_M33[0], com_p_M33[1], com_p_M33[2])

        # set up initial conditions (M33 pos and velocity relative to M31)
        self.r0 = (com_p_M33 - com_p_M31).value # separation vector in kpc
        self.v0 = (com_v_M33 - com_v_M31).value # relative velocity in km/s
             
            
            
        # set up M31 potential parameters
        
        # M31 disk
        self.rdisk = 5.0 # disk scale length in kpc
        self.Mdisk = ComponentMass("M31_000.txt", 2)*1e12 # disk mass in Msun
        
        # M31 bulge
        self.rbulge = 1.0 # bulge scale length in kpc
        self.Mbulge = ComponentMass("M31_000.txt", 3)*1e12 # bulge mass in Msun
        
        # M31 Halo
        self.rhalo = 61.58 # Halo Scale Length: use the Hernquist scale length, computed in HW5
        self.Mhalo = ComponentMass("M31_000.txt", 1)*1e12  # halo mass in Msun
     
        
        ### ADD M33 HALO MASS HERE #### 
        self.M33halo = ComponentMass("M33_000.txt", 1)*1e12 # halo mass in Msun
    
        ### ADD M31 CIRCULAR SPEED HERE ### 
        self.Vc = 180 #Circular speed in km/s for M31 in Homework5
        
        ### Fudge factor ## 
        self.fudge = 1.0
    
    
    
    def HernquistAccel(self, M, r_a, r):
        '''
        This method computes the 3-D acceleration due to a Hernquist potential.

        PARAMETERS
        ----------
        M : `float`
            Total mass responsible for the potential in Msun
        r_a : `float`
            Scale length in kpc
        r : `np.ndarray`
            Position vector to find the acceleration at

        RETURNS
        -------
        a : `np.ndarray`
            Acceleration vector in kpc/Gyr^2
        '''

        # follow the formula in the HW instructions
        r_mag = np.sqrt(np.sum(r**2))
        
        # Acceleration for a Hernquist Potential
        # Terms that are constant per component
        M_const = self.G * M / (r_mag * (r_a + r_mag)**2) 
        a = -M_const*r # acceleration per component
        
        return a
    
    
    
    def MiyamotoNagaiAccel(self, M, rd, r):
        '''
        This method computes the 3-D acceleration due to a Miyamoto-Nagai disk.

        PARAMETERS
        ----------
        M : `float`
            Disk mass responsible for the potential in Msun
        r_d : `float`
            Disk scale length in kpc
        r : `np.ndarray`
            Position vector to find the acceleration (kpc)

        RETURNS
        -------
        a : `np.ndarray`
            Acceleration vector in kpc/Gyr^2
        '''
        # follow the formula for a Miyamoto-Nagai Disk from the HW instructions
       
        # Intermediate Terms
        R2 = np.sum(r[:2]**2)
        zd = rd / 5.0
        B = rd + np.sqrt(r[2]**2 + zd**2)
        
        # constant term in all three components
        M_const = self.G * M / (R2 + B**2)**1.5
        
        # vector of additional terms
        # the np.array allows for a different value for the z component of the acceleration
        vec = np.array([1., 1., B/np.sqrt(r[2]**2 + zd**2)])
        
        # Acceleration
        a = -M_const*vec*r
       
        return a
     
    
    ########### ADD Dynamical Friction Method Here ##################
    def DynamicalFriction(self, Msat, Vc, r, v):
        '''
        Method that returns the deceleration from
        dynamical friction felt by M33 owing to its
        motion through the dark matter halo of M31

        Parameters:
            Msat : `float`
                mass of M33 in Msun
            Vc : `float`
                circular velocity of M31 in km/s   
            r : `np.ndarray`
                position vector of M33 in kpc
            v : `np.ndarray`
                velocity vector of M33 in km/s relative to the host
        Returns:
            DF: `np.ndarray`
                deceleration vector owing to dynamical friction
            
        '''
        r_mag = np.sqrt(r[0]**2 + r[1]**2 + r[2]**2) # magnitude of the position vector of the satellite
        v_mag = np.sqrt(v[0]**2 + v[1]**2 + v[2]**2) # magnitude of the velocity vector of the satellite

        #For the Coulomb Logarithm
        bmax = r_mag #current separation of M33 from M31
        
        #bmin: radius of a strong encounter
        #G Msat / Vc**2
        bmin = self.G * Msat / Vc**2 #minimum impact parameter, set to 0.1 kpc

        #Coulomb Logarithm
        Coulomb = np.log(bmax/bmin) #Coulomb logarithm

        #Dynamical Friction
        DF = -0.428*self.G*Msat*Coulomb/r_mag**2 *v/v_mag*self.fudge

        return DF
        
        
     ##### ADD v to M31Accel input #### 
    def M31Accel(self, r, v):
        '''
        This method computes the 3-D acceleration due to M31.

        PARAMETERS
        ----------
        r : `np.ndarray`
            Position vector to find the acceleration at 

        v : `np.ndarray`
            Velocity vector of M33 in km/s relative to the host, DF calculation (km/s)

        RETURNS
        -------
        a : `np.ndarray`
            Acceleration vector in kpc/Gyr^2
        '''
        
        # Compute the acceleration from each galaxy component
        ahalo = self.HernquistAccel(self.Mhalo, self.rhalo, r) 
        abulge = self.HernquistAccel(self.Mbulge, self.rbulge, r) 
        adisk = self.MiyamotoNagaiAccel(self.Mdisk, self.rdisk, r)
    
        ###### ADD DYNAMICAL FRICTION HERE and include in "a"
        aDF = self.DynamicalFriction(self.M33halo, self.Vc, r, v)

        a = ahalo+abulge+adisk+aDF
        
        return a # return the total acceleration
    
    
    def LeapFrog(self, dt, r, v):
        '''This method is a leapfrog integrator for evolving the position
        and velocity of M33 in time. One call produces one timestep.

        PARAMETERS
        ----------
        dt : `float`
            timestep in Gyr
        r : `np.ndarray`
            position vector at the start of the timestep in kpc
        v : `np.ndarray`
            velocity vector at the start of the timestep in km/s

        RETURNS
        -------
        rnext : `np.ndarray`
            position vector at the end of the timestep in kpc
        vnext : `np.ndarray`
            velocity vector at the end of the timestep in km/s
        '''
        
        # predict the position at the next half timestep
        r_half = r + v * (dt / 2.0)
        
        # compute the velocity at the next timestep
        ##### ADD v as input to M31Accel ### 
        vnext = v + self.M31Accel(r_half, v) * dt
        
        # compute the position at the next timestep
        rnext = r + (vnext+v) * dt / 2.0
        
        return rnext, vnext
    
    
    
    def OrbitIntegration(self, t0, dt, tmax):
        '''This method integrates the orbit of M33 and stores the position
            and velocity of M33 (in the COM frame of M31) at each timestep in a file. 

        PARAMETERS
        ----------
        t0 : `float`
            Start time in Gyr
        dt : `float`
            Timestep in Gyr
        tmax : `float`
            End time in Gyr
        ''' 
        
        # find out how many timesteps we have
        N_steps = int((tmax - t0)/dt)+1 # add 1 to account for the integer rounding
        
        # set up orbit array, two more rows than t/dt allow for storing the ICs
        # and account for the rounding of the number of time intervals to an integer
        orbit = np.zeros([N_steps+1, 7]) # first row will be for the ICs
        #orbit = np.zeros([int(tmax/dt)+2, 7])
        
        
        
        # initialize the time , position, velocity
        t = t0 # initial time
        r = self.r0 # initial p
        v = self.v0 # initial v
        
        # and store the ICs for M33 in the first row of the orbit file
        # Initial time, initial position relative to M31, initial velocity relative to M31
        orbit[0] = t0, *tuple(r), *tuple(v)
        
        
        i = 1 # step counter, starts at 1 since the 0th timestep is the ICs above.
        
        # start the integration
        while (t < tmax):
            # update time
            t += dt
            
            # update positions and velocities with the leapfrog function
            r, v = self.LeapFrog(dt, r, v)
            
            # store system state
            orbit[i] = t, *tuple(r), *tuple(v)
            
            # print progress and increment step counter
            print(f'Finished step {i} of {N_steps}') 
            
            i += 1 # update counter
        
        # write the data to a file
        np.savetxt(self.filename, orbit, fmt = "%11.3f"*7, comments='#', 
                   header="{:>10s}{:>11s}{:>11s}{:>11s}{:>11s}{:>11s}{:>11s}"\
                   .format('t', 'x', 'y', 'z', 'vx', 'vy', 'vz'))

# %%
# ------------------ FUNCTIONS -------------------# 

# Set the format for reading in the orbit data files   
orbit_type = np.dtype([('t', 'f8'), ('r', 'f8', 3), ('v', 'f8', 3)])


def relative_mag(orbit1, orbit2): 
    """ Function to compute the relative separation and velocity using input orbit files for two galaxies, 
    where the orbit files have `orbit_type` formatting: np.dtype([('t', 'f8'), ('r', 'f8', 3), ('v', 'f8', 3)])

    PARAMETERS
    ----------
    orbit1 : `np.ndarray' 
        first vector, assumed 'orbit_type' formatting
    orbit2 : 'np.ndarray'
        second vector, assumed 'orbit_type' formatting
    RETURNS
    -------
    rel_pos : `float or np.ndarray`
            |pos1 - pos2|
    rel_vel :`float or np.ndarray`
            |vel1 - vel2|
    """
    
    rel_pos = np.sqrt(np.sum((orbit1['r'] - orbit2['r'])**2, axis=1))
    rel_vel = np.sqrt(np.sum((orbit1['v'] - orbit2['v'])**2, axis=1))
    
    return rel_pos,rel_vel
                  
                  
def vector_mag(orbit):
    """ Function to compute the magnitude of the separation and velocity using an input orbit file, 
    where the orbit files have `orbit_type` formatting: np.dtype([('t', 'f8'), ('r', 'f8', 3), ('v', 'f8', 3)])

    PARAMETERS
    ----------
    orbit : `np.ndarray' 
        vector, assumed 'orbit_type' formatting
        
    RETURNS
    --------
    pos : `float or np.ndarray`
         magnitude of the position
    vel : `float or np.ndarray`
         magnitude of the position  
    
    """              
    pos = np.sqrt(np.sum(orbit['r']**2, axis=1)) 
    vel = np.sqrt(np.sum(orbit['v']**2, axis=1))
                      
    return pos, vel

# %%
# ------------------- MAIN ---------------------- #


# make instance of the orbit integrator class
M33 = M33AnalyticOrbit("M33AnalyticOrbit_withDF.txt")

# Compute the orbit
M33.OrbitIntegration(0, 0.001, 10)
# Out:
# Finished step 1 of 10001
# Finished step 2 of 10001
# Finished step 3 of 10001
# Finished step 4 of 10001
# Finished step 5 of 10001
# Finished step 6 of 10001
# Finished step 7 of 10001
# Finished step 8 of 10001
# Finished step 9 of 10001
# Finished step 10 of 10001
# Finished step 11 of 10001
# Finished step 12 of 10001
# Finished step 13 of 10001
# Finished step 14 of 10001
# Finished step 15 of 10001
# Finished step 16 of 10001
# Finished step 17 of 10001
# Finished step 18 of 10001
# Finished step 19 of 10001
# Finished step 20 of 10001
# Finished step 21 of 10001
# Finished step 22 of 10001
# Finished step 23 of 10001
# Finished step 24 of 10001
# Finished step 25 of 10001
# Finished step 26 of 10001
# Finished step 27 of 10001
# Finished step 28 of 10001
# Finished step 29 of 10001
# Finished step 30 of 10001
# Finished step 31 of 10001
# Finished step 32 of 10001
# Finished step 33 of 10001
# Finished step 34 of 10001
# Finished step 35 of 10001
# Finished step 36 of 10001
# Finished step 37 of 10001
# Finished step 38 of 10001
# Finished step 39 of 10001
# Finished step 40 of 10001
# Finished step 41 of 10001
# Finished step 42 of 10001
# Finished step 43 of 10001
# Finished step 44 of 10001
# Finished step 45 of 10001
# Finished step 46 of 10001
# Finished step 47 of 10001
# Finished step 48 of 10001
# Finished step 49 of 10001
# Finished step 50 of 10001
# Finished step 51 of 10001
# Finished step 52 of 10001
# Finished step 53 of 10001
# Finished step 54 of 10001
# Finished step 55 of 10001
# Finished step 56 of 10001
# Finished step 57 of 10001
# Finished step 58 of 10001
# Finished step 59 of 10001
# Finished step 60 of 10001
# Finished step 61 of 10001
# Finished step 62 of 10001
# Finished step 63 of 10001
# Finished step 64 of 10001
# Finished step 65 of 10001
# Finished step 66 of 10001
# Finished step 67 of 10001
# Finished step 68 of 10001
# Finished step 69 of 10001
# Finished step 70 of 10001
# Finished step 71 of 10001
# Finished step 72 of 10001
# Finished step 73 of 10001
# Finished step 74 of 10001
# Finished step 75 of 10001
# Finished step 76 of 10001
# Finished step 77 of 10001
# Finished step 78 of 10001
# Finished step 79 of 10001
# Finished step 80 of 10001
# Finished step 81 of 10001
# Finished step 82 of 10001
# Finished step 83 of 10001
# Finished step 84 of 10001
# Finished step 85 of 10001
# Finished step 86 of 10001
# Finished step 87 of 10001
# Finished step 88 of 10001
# Finished step 89 of 10001
# Finished step 90 of 10001
# Finished step 91 of 10001
# Finished step 92 of 10001
# Finished step 93 of 10001
# Finished step 94 of 10001
# Finished step 95 of 10001
# Finished step 96 of 10001
# Finished step 97 of 10001
# Finished step 98 of 10001
# Finished step 99 of 10001
# Finished step 100 of 10001
# Finished step 101 of 10001
# Finished step 102 of 10001
# Finished step 103 of 10001
# Finished step 104 of 10001
# Finished step 105 of 10001
# Finished step 106 of 10001
# Finished step 107 of 10001
# Finished step 108 of 10001
# Finished step 109 of 10001
# Finished step 110 of 10001
# Finished step 111 of 10001
# Finished step 112 of 10001
# Finished step 113 of 10001
# Finished step 114 of 10001
# Finished step 115 of 10001
# Finished step 116 of 10001
# Finished step 117 of 10001
# Finished step 118 of 10001
# Finished step 119 of 10001
# Finished step 120 of 10001
# Finished step 121 of 10001
# Finished step 122 of 10001
# Finished step 123 of 10001
# Finished step 124 of 10001
# Finished step 125 of 10001
# Finished step 126 of 10001
# Finished step 127 of 10001
# Finished step 128 of 10001
# Finished step 129 of 10001
# Finished step 130 of 10001
# Finished step 131 of 10001
# Finished step 132 of 10001
# Finished step 133 of 10001
# Finished step 134 of 10001
# Finished step 135 of 10001
# Finished step 136 of 10001
# Finished step 137 of 10001
# Finished step 138 of 10001
# Finished step 139 of 10001
# Finished step 140 of 10001
# Finished step 141 of 10001
# Finished step 142 of 10001
# Finished step 143 of 10001
# Finished step 144 of 10001
# Finished step 145 of 10001
# Finished step 146 of 10001
# Finished step 147 of 10001
# Finished step 148 of 10001
# Finished step 149 of 10001
# Finished step 150 of 10001
# Finished step 151 of 10001
# Finished step 152 of 10001
# Finished step 153 of 10001
# Finished step 154 of 10001
# Finished step 155 of 10001
# Finished step 156 of 10001
# Finished step 157 of 10001
# Finished step 158 of 10001
# Finished step 159 of 10001
# Finished step 160 of 10001
# Finished step 161 of 10001
# Finished step 162 of 10001
# Finished step 163 of 10001
# Finished step 164 of 10001
# Finished step 165 of 10001
# Finished step 166 of 10001
# Finished step 167 of 10001
# Finished step 168 of 10001
# Finished step 169 of 10001
# Finished step 170 of 10001
# Finished step 171 of 10001
# Finished step 172 of 10001
# Finished step 173 of 10001
# Finished step 174 of 10001
# Finished step 175 of 10001
# Finished step 176 of 10001
# Finished step 177 of 10001
# Finished step 178 of 10001
# Finished step 179 of 10001
# Finished step 180 of 10001
# Finished step 181 of 10001
# Finished step 182 of 10001
# Finished step 183 of 10001
# Finished step 184 of 10001
# Finished step 185 of 10001
# Finished step 186 of 10001
# Finished step 187 of 10001
# Finished step 188 of 10001
# Finished step 189 of 10001
# Finished step 190 of 10001
# Finished step 191 of 10001
# Finished step 192 of 10001
# Finished step 193 of 10001
# Finished step 194 of 10001
# Finished step 195 of 10001
# Finished step 196 of 10001
# Finished step 197 of 10001
# Finished step 198 of 10001
# Finished step 199 of 10001
# Finished step 200 of 10001
# Finished step 201 of 10001
# Finished step 202 of 10001
# Finished step 203 of 10001
# Finished step 204 of 10001
# Finished step 205 of 10001
# Finished step 206 of 10001
# Finished step 207 of 10001
# Finished step 208 of 10001
# Finished step 209 of 10001
# Finished step 210 of 10001
# Finished step 211 of 10001
# Finished step 212 of 10001
# Finished step 213 of 10001
# Finished step 214 of 10001
# Finished step 215 of 10001
# Finished step 216 of 10001
# Finished step 217 of 10001
# Finished step 218 of 10001
# Finished step 219 of 10001
# Finished step 220 of 10001
# Finished step 221 of 10001
# Finished step 222 of 10001
# Finished step 223 of 10001
# Finished step 224 of 10001
# Finished step 225 of 10001
# Finished step 226 of 10001
# Finished step 227 of 10001
# Finished step 228 of 10001
# Finished step 229 of 10001
# Finished step 230 of 10001
# Finished step 231 of 10001
# Finished step 232 of 10001
# Finished step 233 of 10001
# Finished step 234 of 10001
# Finished step 235 of 10001
# Finished step 236 of 10001
# Finished step 237 of 10001
# Finished step 238 of 10001
# Finished step 239 of 10001
# Finished step 240 of 10001
# Finished step 241 of 10001
# Finished step 242 of 10001
# Finished step 243 of 10001
# Finished step 244 of 10001
# Finished step 245 of 10001
# Finished step 246 of 10001
# Finished step 247 of 10001
# Finished step 248 of 10001
# Finished step 249 of 10001
# Finished step 250 of 10001
# Finished step 251 of 10001
# Finished step 252 of 10001
# Finished step 253 of 10001
# Finished step 254 of 10001
# Finished step 255 of 10001
# Finished step 256 of 10001
# Finished step 257 of 10001
# Finished step 258 of 10001
# Finished step 259 of 10001
# Finished step 260 of 10001
# Finished step 261 of 10001
# Finished step 262 of 10001
# Finished step 263 of 10001
# Finished step 264 of 10001
# Finished step 265 of 10001
# Finished step 266 of 10001
# Finished step 267 of 10001
# Finished step 268 of 10001
# Finished step 269 of 10001
# Finished step 270 of 10001
# Finished step 271 of 10001
# Finished step 272 of 10001
# Finished step 273 of 10001
# Finished step 274 of 10001
# Finished step 275 of 10001
# Finished step 276 of 10001
# Finished step 277 of 10001
# Finished step 278 of 10001
# Finished step 279 of 10001
# Finished step 280 of 10001
# Finished step 281 of 10001
# Finished step 282 of 10001
# Finished step 283 of 10001
# Finished step 284 of 10001
# Finished step 285 of 10001
# Finished step 286 of 10001
# Finished step 287 of 10001
# Finished step 288 of 10001
# Finished step 289 of 10001
# Finished step 290 of 10001
# Finished step 291 of 10001
# Finished step 292 of 10001
# Finished step 293 of 10001
# Finished step 294 of 10001
# Finished step 295 of 10001
# Finished step 296 of 10001
# Finished step 297 of 10001
# Finished step 298 of 10001
# Finished step 299 of 10001
# Finished step 300 of 10001
# Finished step 301 of 10001
# Finished step 302 of 10001
# Finished step 303 of 10001
# Finished step 304 of 10001
# Finished step 305 of 10001
# Finished step 306 of 10001
# Finished step 307 of 10001
# Finished step 308 of 10001
# Finished step 309 of 10001
# Finished step 310 of 10001
# Finished step 311 of 10001
# Finished step 312 of 10001
# Finished step 313 of 10001
# Finished step 314 of 10001
# Finished step 315 of 10001
# Finished step 316 of 10001
# Finished step 317 of 10001
# Finished step 318 of 10001
# Finished step 319 of 10001
# Finished step 320 of 10001
# Finished step 321 of 10001
# Finished step 322 of 10001
# Finished step 323 of 10001
# Finished step 324 of 10001
# Finished step 325 of 10001
# Finished step 326 of 10001
# Finished step 327 of 10001
# Finished step 328 of 10001
# Finished step 329 of 10001
# Finished step 330 of 10001
# Finished step 331 of 10001
# Finished step 332 of 10001
# Finished step 333 of 10001
# Finished step 334 of 10001
# Finished step 335 of 10001
# Finished step 336 of 10001
# Finished step 337 of 10001
# Finished step 338 of 10001
# Finished step 339 of 10001
# Finished step 340 of 10001
# Finished step 341 of 10001
# Finished step 342 of 10001
# Finished step 343 of 10001
# Finished step 344 of 10001
# Finished step 345 of 10001
# Finished step 346 of 10001
# Finished step 347 of 10001
# Finished step 348 of 10001
# Finished step 349 of 10001
# Finished step 350 of 10001
# Finished step 351 of 10001
# Finished step 352 of 10001
# Finished step 353 of 10001
# Finished step 354 of 10001
# Finished step 355 of 10001
# Finished step 356 of 10001
# Finished step 357 of 10001
# Finished step 358 of 10001
# Finished step 359 of 10001
# Finished step 360 of 10001
# Finished step 361 of 10001
# Finished step 362 of 10001
# Finished step 363 of 10001
# Finished step 364 of 10001
# Finished step 365 of 10001
# Finished step 366 of 10001
# Finished step 367 of 10001
# Finished step 368 of 10001
# Finished step 369 of 10001
# Finished step 370 of 10001
# Finished step 371 of 10001
# Finished step 372 of 10001
# Finished step 373 of 10001
# Finished step 374 of 10001
# Finished step 375 of 10001
# Finished step 376 of 10001
# Finished step 377 of 10001
# Finished step 378 of 10001
# Finished step 379 of 10001
# Finished step 380 of 10001
# Finished step 381 of 10001
# Finished step 382 of 10001
# Finished step 383 of 10001
# Finished step 384 of 10001
# Finished step 385 of 10001
# Finished step 386 of 10001
# Finished step 387 of 10001
# Finished step 388 of 10001
# Finished step 389 of 10001
# Finished step 390 of 10001
# Finished step 391 of 10001
# Finished step 392 of 10001
# Finished step 393 of 10001
# Finished step 394 of 10001
# Finished step 395 of 10001
# Finished step 396 of 10001
# Finished step 397 of 10001
# Finished step 398 of 10001
# Finished step 399 of 10001
# Finished step 400 of 10001
# Finished step 401 of 10001
# Finished step 402 of 10001
# Finished step 403 of 10001
# Finished step 404 of 10001
# Finished step 405 of 10001
# Finished step 406 of 10001
# Finished step 407 of 10001
# Finished step 408 of 10001
# Finished step 409 of 10001
# Finished step 410 of 10001
# Finished step 411 of 10001
# Finished step 412 of 10001
# Finished step 413 of 10001
# Finished step 414 of 10001
# Finished step 415 of 10001
# Finished step 416 of 10001
# Finished step 417 of 10001
# Finished step 418 of 10001
# Finished step 419 of 10001
# Finished step 420 of 10001
# Finished step 421 of 10001
# Finished step 422 of 10001
# Finished step 423 of 10001
# Finished step 424 of 10001
# Finished step 425 of 10001
# Finished step 426 of 10001
# Finished step 427 of 10001
# Finished step 428 of 10001
# Finished step 429 of 10001
# Finished step 430 of 10001
# Finished step 431 of 10001
# Finished step 432 of 10001
# Finished step 433 of 10001
# Finished step 434 of 10001
# Finished step 435 of 10001
# Finished step 436 of 10001
# Finished step 437 of 10001
# Finished step 438 of 10001
# Finished step 439 of 10001
# Finished step 440 of 10001
# Finished step 441 of 10001
# Finished step 442 of 10001
# Finished step 443 of 10001
# Finished step 444 of 10001
# Finished step 445 of 10001
# Finished step 446 of 10001
# Finished step 447 of 10001
# Finished step 448 of 10001
# Finished step 449 of 10001
# Finished step 450 of 10001
# Finished step 451 of 10001
# Finished step 452 of 10001
# Finished step 453 of 10001
# Finished step 454 of 10001
# Finished step 455 of 10001
# Finished step 456 of 10001
# Finished step 457 of 10001
# Finished step 458 of 10001
# Finished step 459 of 10001
# Finished step 460 of 10001
# Finished step 461 of 10001
# Finished step 462 of 10001
# Finished step 463 of 10001
# Finished step 464 of 10001
# Finished step 465 of 10001
# Finished step 466 of 10001
# Finished step 467 of 10001
# Finished step 468 of 10001
# Finished step 469 of 10001
# Finished step 470 of 10001
# Finished step 471 of 10001
# Finished step 472 of 10001
# Finished step 473 of 10001
# Finished step 474 of 10001
# Finished step 475 of 10001
# Finished step 476 of 10001
# Finished step 477 of 10001
# Finished step 478 of 10001
# Finished step 479 of 10001
# Finished step 480 of 10001
# Finished step 481 of 10001
# Finished step 482 of 10001
# Finished step 483 of 10001
# Finished step 484 of 10001
# Finished step 485 of 10001
# Finished step 486 of 10001
# Finished step 487 of 10001
# Finished step 488 of 10001
# Finished step 489 of 10001
# Finished step 490 of 10001
# Finished step 491 of 10001
# Finished step 492 of 10001
# Finished step 493 of 10001
# Finished step 494 of 10001
# Finished step 495 of 10001
# Finished step 496 of 10001
# Finished step 497 of 10001
# Finished step 498 of 10001
# Finished step 499 of 10001
# Finished step 500 of 10001
# Finished step 501 of 10001
# Finished step 502 of 10001
# Finished step 503 of 10001
# Finished step 504 of 10001
# Finished step 505 of 10001
# Finished step 506 of 10001
# Finished step 507 of 10001
# Finished step 508 of 10001
# Finished step 509 of 10001
# Finished step 510 of 10001
# Finished step 511 of 10001
# Finished step 512 of 10001
# Finished step 513 of 10001
# Finished step 514 of 10001
# Finished step 515 of 10001
# Finished step 516 of 10001
# Finished step 517 of 10001
# Finished step 518 of 10001
# Finished step 519 of 10001
# Finished step 520 of 10001
# Finished step 521 of 10001
# Finished step 522 of 10001
# Finished step 523 of 10001
# Finished step 524 of 10001
# Finished step 525 of 10001
# Finished step 526 of 10001
# Finished step 527 of 10001
# Finished step 528 of 10001
# Finished step 529 of 10001
# Finished step 530 of 10001
# Finished step 531 of 10001
# Finished step 532 of 10001
# Finished step 533 of 10001
# Finished step 534 of 10001
# Finished step 535 of 10001
# Finished step 536 of 10001
# Finished step 537 of 10001
# Finished step 538 of 10001
# Finished step 539 of 10001
# Finished step 540 of 10001
# Finished step 541 of 10001
# Finished step 542 of 10001
# Finished step 543 of 10001
# Finished step 544 of 10001
# Finished step 545 of 10001
# Finished step 546 of 10001
# Finished step 547 of 10001
# Finished step 548 of 10001
# Finished step 549 of 10001
# Finished step 550 of 10001
# Finished step 551 of 10001
# Finished step 552 of 10001
# Finished step 553 of 10001
# Finished step 554 of 10001
# Finished step 555 of 10001
# Finished step 556 of 10001
# Finished step 557 of 10001
# Finished step 558 of 10001
# Finished step 559 of 10001
# Finished step 560 of 10001
# Finished step 561 of 10001
# Finished step 562 of 10001
# Finished step 563 of 10001
# Finished step 564 of 10001
# Finished step 565 of 10001
# Finished step 566 of 10001
# Finished step 567 of 10001
# Finished step 568 of 10001
# Finished step 569 of 10001
# Finished step 570 of 10001
# Finished step 571 of 10001
# Finished step 572 of 10001
# Finished step 573 of 10001
# Finished step 574 of 10001
# Finished step 575 of 10001
# Finished step 576 of 10001
# Finished step 577 of 10001
# Finished step 578 of 10001
# Finished step 579 of 10001
# Finished step 580 of 10001
# Finished step 581 of 10001
# Finished step 582 of 10001
# Finished step 583 of 10001
# Finished step 584 of 10001
# Finished step 585 of 10001
# Finished step 586 of 10001
# Finished step 587 of 10001
# Finished step 588 of 10001
# Finished step 589 of 10001
# Finished step 590 of 10001
# Finished step 591 of 10001
# Finished step 592 of 10001
# Finished step 593 of 10001
# Finished step 594 of 10001
# Finished step 595 of 10001
# Finished step 596 of 10001
# Finished step 597 of 10001
# Finished step 598 of 10001
# Finished step 599 of 10001
# Finished step 600 of 10001
# Finished step 601 of 10001
# Finished step 602 of 10001
# Finished step 603 of 10001
# Finished step 604 of 10001
# Finished step 605 of 10001
# Finished step 606 of 10001
# Finished step 607 of 10001
# Finished step 608 of 10001
# Finished step 609 of 10001
# Finished step 610 of 10001
# Finished step 611 of 10001
# Finished step 612 of 10001
# Finished step 613 of 10001
# Finished step 614 of 10001
# Finished step 615 of 10001
# Finished step 616 of 10001
# Finished step 617 of 10001
# Finished step 618 of 10001
# Finished step 619 of 10001
# Finished step 620 of 10001
# Finished step 621 of 10001
# Finished step 622 of 10001
# Finished step 623 of 10001
# Finished step 624 of 10001
# Finished step 625 of 10001
# Finished step 626 of 10001
# Finished step 627 of 10001
# Finished step 628 of 10001
# Finished step 629 of 10001
# Finished step 630 of 10001
# Finished step 631 of 10001
# Finished step 632 of 10001
# Finished step 633 of 10001
# Finished step 634 of 10001
# Finished step 635 of 10001
# Finished step 636 of 10001
# Finished step 637 of 10001
# Finished step 638 of 10001
# Finished step 639 of 10001
# Finished step 640 of 10001
# Finished step 641 of 10001
# Finished step 642 of 10001
# Finished step 643 of 10001
# Finished step 644 of 10001
# Finished step 645 of 10001
# Finished step 646 of 10001
# Finished step 647 of 10001
# Finished step 648 of 10001
# Finished step 649 of 10001
# Finished step 650 of 10001
# Finished step 651 of 10001
# Finished step 652 of 10001
# Finished step 653 of 10001
# Finished step 654 of 10001
# Finished step 655 of 10001
# Finished step 656 of 10001
# Finished step 657 of 10001
# Finished step 658 of 10001
# Finished step 659 of 10001
# Finished step 660 of 10001
# Finished step 661 of 10001
# Finished step 662 of 10001
# Finished step 663 of 10001
# Finished step 664 of 10001
# Finished step 665 of 10001
# Finished step 666 of 10001
# Finished step 667 of 10001
# Finished step 668 of 10001
# Finished step 669 of 10001
# Finished step 670 of 10001
# Finished step 671 of 10001
# Finished step 672 of 10001
# Finished step 673 of 10001
# Finished step 674 of 10001
# Finished step 675 of 10001
# Finished step 676 of 10001
# Finished step 677 of 10001
# Finished step 678 of 10001
# Finished step 679 of 10001
# Finished step 680 of 10001
# Finished step 681 of 10001
# Finished step 682 of 10001
# Finished step 683 of 10001
# Finished step 684 of 10001
# Finished step 685 of 10001
# Finished step 686 of 10001
# Finished step 687 of 10001
# Finished step 688 of 10001
# Finished step 689 of 10001
# Finished step 690 of 10001
# Finished step 691 of 10001
# Finished step 692 of 10001
# Finished step 693 of 10001
# Finished step 694 of 10001
# Finished step 695 of 10001
# Finished step 696 of 10001
# Finished step 697 of 10001
# Finished step 698 of 10001
# Finished step 699 of 10001
# Finished step 700 of 10001
# Finished step 701 of 10001
# Finished step 702 of 10001
# Finished step 703 of 10001
# Finished step 704 of 10001
# Finished step 705 of 10001
# Finished step 706 of 10001
# Finished step 707 of 10001
# Finished step 708 of 10001
# Finished step 709 of 10001
# Finished step 710 of 10001
# Finished step 711 of 10001
# Finished step 712 of 10001
# Finished step 713 of 10001
# Finished step 714 of 10001
# Finished step 715 of 10001
# Finished step 716 of 10001
# Finished step 717 of 10001
# Finished step 718 of 10001
# Finished step 719 of 10001
# Finished step 720 of 10001
# Finished step 721 of 10001
# Finished step 722 of 10001
# Finished step 723 of 10001
# Finished step 724 of 10001
# Finished step 725 of 10001
# Finished step 726 of 10001
# Finished step 727 of 10001
# Finished step 728 of 10001
# Finished step 729 of 10001
# Finished step 730 of 10001
# Finished step 731 of 10001
# Finished step 732 of 10001
# Finished step 733 of 10001
# Finished step 734 of 10001
# Finished step 735 of 10001
# Finished step 736 of 10001
# Finished step 737 of 10001
# Finished step 738 of 10001
# Finished step 739 of 10001
# Finished step 740 of 10001
# Finished step 741 of 10001
# Finished step 742 of 10001
# Finished step 743 of 10001
# Finished step 744 of 10001
# Finished step 745 of 10001
# Finished step 746 of 10001
# Finished step 747 of 10001
# Finished step 748 of 10001
# Finished step 749 of 10001
# Finished step 750 of 10001
# Finished step 751 of 10001
# Finished step 752 of 10001
# Finished step 753 of 10001
# Finished step 754 of 10001
# Finished step 755 of 10001
# Finished step 756 of 10001
# Finished step 757 of 10001
# Finished step 758 of 10001
# Finished step 759 of 10001
# Finished step 760 of 10001
# Finished step 761 of 10001
# Finished step 762 of 10001
# Finished step 763 of 10001
# Finished step 764 of 10001
# Finished step 765 of 10001
# Finished step 766 of 10001
# Finished step 767 of 10001
# Finished step 768 of 10001
# Finished step 769 of 10001
# Finished step 770 of 10001
# Finished step 771 of 10001
# Finished step 772 of 10001
# Finished step 773 of 10001
# Finished step 774 of 10001
# Finished step 775 of 10001
# Finished step 776 of 10001
# Finished step 777 of 10001
# Finished step 778 of 10001
# Finished step 779 of 10001
# Finished step 780 of 10001
# Finished step 781 of 10001
# Finished step 782 of 10001
# Finished step 783 of 10001
# Finished step 784 of 10001
# Finished step 785 of 10001
# Finished step 786 of 10001
# Finished step 787 of 10001
# Finished step 788 of 10001
# Finished step 789 of 10001
# Finished step 790 of 10001
# Finished step 791 of 10001
# Finished step 792 of 10001
# Finished step 793 of 10001
# Finished step 794 of 10001
# Finished step 795 of 10001
# Finished step 796 of 10001
# Finished step 797 of 10001
# Finished step 798 of 10001
# Finished step 799 of 10001
# Finished step 800 of 10001
# Finished step 801 of 10001
# Finished step 802 of 10001
# Finished step 803 of 10001
# Finished step 804 of 10001
# Finished step 805 of 10001
# Finished step 806 of 10001
# Finished step 807 of 10001
# Finished step 808 of 10001
# Finished step 809 of 10001
# Finished step 810 of 10001
# Finished step 811 of 10001
# Finished step 812 of 10001
# Finished step 813 of 10001
# Finished step 814 of 10001
# Finished step 815 of 10001
# Finished step 816 of 10001
# Finished step 817 of 10001
# Finished step 818 of 10001
# Finished step 819 of 10001
# Finished step 820 of 10001
# Finished step 821 of 10001
# Finished step 822 of 10001
# Finished step 823 of 10001
# Finished step 824 of 10001
# Finished step 825 of 10001
# Finished step 826 of 10001
# Finished step 827 of 10001
# Finished step 828 of 10001
# Finished step 829 of 10001
# Finished step 830 of 10001
# Finished step 831 of 10001
# Finished step 832 of 10001
# Finished step 833 of 10001
# Finished step 834 of 10001
# Finished step 835 of 10001
# Finished step 836 of 10001
# Finished step 837 of 10001
# Finished step 838 of 10001
# Finished step 839 of 10001
# Finished step 840 of 10001
# Finished step 841 of 10001
# Finished step 842 of 10001
# Finished step 843 of 10001
# Finished step 844 of 10001
# Finished step 845 of 10001
# Finished step 846 of 10001
# Finished step 847 of 10001
# Finished step 848 of 10001
# Finished step 849 of 10001
# Finished step 850 of 10001
# Finished step 851 of 10001
# Finished step 852 of 10001
# Finished step 853 of 10001
# Finished step 854 of 10001
# Finished step 855 of 10001
# Finished step 856 of 10001
# Finished step 857 of 10001
# Finished step 858 of 10001
# Finished step 859 of 10001
# Finished step 860 of 10001
# Finished step 861 of 10001
# Finished step 862 of 10001
# Finished step 863 of 10001
# Finished step 864 of 10001
# Finished step 865 of 10001
# Finished step 866 of 10001
# Finished step 867 of 10001
# Finished step 868 of 10001
# Finished step 869 of 10001
# Finished step 870 of 10001
# Finished step 871 of 10001
# Finished step 872 of 10001
# Finished step 873 of 10001
# Finished step 874 of 10001
# Finished step 875 of 10001
# Finished step 876 of 10001
# Finished step 877 of 10001
# Finished step 878 of 10001
# Finished step 879 of 10001
# Finished step 880 of 10001
# Finished step 881 of 10001
# Finished step 882 of 10001
# Finished step 883 of 10001
# Finished step 884 of 10001
# Finished step 885 of 10001
# Finished step 886 of 10001
# Finished step 887 of 10001
# Finished step 888 of 10001
# Finished step 889 of 10001
# Finished step 890 of 10001
# Finished step 891 of 10001
# Finished step 892 of 10001
# Finished step 893 of 10001
# Finished step 894 of 10001
# Finished step 895 of 10001
# Finished step 896 of 10001
# Finished step 897 of 10001
# Finished step 898 of 10001
# Finished step 899 of 10001
# Finished step 900 of 10001
# Finished step 901 of 10001
# Finished step 902 of 10001
# Finished step 903 of 10001
# Finished step 904 of 10001
# Finished step 905 of 10001
# Finished step 906 of 10001
# Finished step 907 of 10001
# Finished step 908 of 10001
# Finished step 909 of 10001
# Finished step 910 of 10001
# Finished step 911 of 10001
# Finished step 912 of 10001
# Finished step 913 of 10001
# Finished step 914 of 10001
# Finished step 915 of 10001
# Finished step 916 of 10001
# Finished step 917 of 10001
# Finished step 918 of 10001
# Finished step 919 of 10001
# Finished step 920 of 10001
# Finished step 921 of 10001
# Finished step 922 of 10001
# Finished step 923 of 10001
# Finished step 924 of 10001
# Finished step 925 of 10001
# Finished step 926 of 10001
# Finished step 927 of 10001
# Finished step 928 of 10001
# Finished step 929 of 10001
# Finished step 930 of 10001
# Finished step 931 of 10001
# Finished step 932 of 10001
# Finished step 933 of 10001
# Finished step 934 of 10001
# Finished step 935 of 10001
# Finished step 936 of 10001
# Finished step 937 of 10001
# Finished step 938 of 10001
# Finished step 939 of 10001
# Finished step 940 of 10001
# Finished step 941 of 10001
# Finished step 942 of 10001
# Finished step 943 of 10001
# Finished step 944 of 10001
# Finished step 945 of 10001
# Finished step 946 of 10001
# Finished step 947 of 10001
# Finished step 948 of 10001
# Finished step 949 of 10001
# Finished step 950 of 10001
# Finished step 951 of 10001
# Finished step 952 of 10001
# Finished step 953 of 10001
# Finished step 954 of 10001
# Finished step 955 of 10001
# Finished step 956 of 10001
# Finished step 957 of 10001
# Finished step 958 of 10001
# Finished step 959 of 10001
# Finished step 960 of 10001
# Finished step 961 of 10001
# Finished step 962 of 10001
# Finished step 963 of 10001
# Finished step 964 of 10001
# Finished step 965 of 10001
# Finished step 966 of 10001
# Finished step 967 of 10001
# Finished step 968 of 10001
# Finished step 969 of 10001
# Finished step 970 of 10001
# Finished step 971 of 10001
# Finished step 972 of 10001
# Finished step 973 of 10001
# Finished step 974 of 10001
# Finished step 975 of 10001
# Finished step 976 of 10001
# Finished step 977 of 10001
# Finished step 978 of 10001
# Finished step 979 of 10001
# Finished step 980 of 10001
# Finished step 981 of 10001
# Finished step 982 of 10001
# Finished step 983 of 10001
# Finished step 984 of 10001
# Finished step 985 of 10001
# Finished step 986 of 10001
# Finished step 987 of 10001
# Finished step 988 of 10001
# Finished step 989 of 10001
# Finished step 990 of 10001
# Finished step 991 of 10001
# Finished step 992 of 10001
# Finished step 993 of 10001
# Finished step 994 of 10001
# Finished step 995 of 10001
# Finished step 996 of 10001
# Finished step 997 of 10001
# Finished step 998 of 10001
# Finished step 999 of 10001
# Finished step 1000 of 10001
# Finished step 1001 of 10001
# Finished step 1002 of 10001
# Finished step 1003 of 10001
# Finished step 1004 of 10001
# Finished step 1005 of 10001
# Finished step 1006 of 10001
# Finished step 1007 of 10001
# Finished step 1008 of 10001
# Finished step 1009 of 10001
# Finished step 1010 of 10001
# Finished step 1011 of 10001
# Finished step 1012 of 10001
# Finished step 1013 of 10001
# Finished step 1014 of 10001
# Finished step 1015 of 10001
# Finished step 1016 of 10001
# Finished step 1017 of 10001
# Finished step 1018 of 10001
# Finished step 1019 of 10001
# Finished step 1020 of 10001
# Finished step 1021 of 10001
# Finished step 1022 of 10001
# Finished step 1023 of 10001
# Finished step 1024 of 10001
# Finished step 1025 of 10001
# Finished step 1026 of 10001
# Finished step 1027 of 10001
# Finished step 1028 of 10001
# Finished step 1029 of 10001
# Finished step 1030 of 10001
# Finished step 1031 of 10001
# Finished step 1032 of 10001
# Finished step 1033 of 10001
# Finished step 1034 of 10001
# Finished step 1035 of 10001
# Finished step 1036 of 10001
# Finished step 1037 of 10001
# Finished step 1038 of 10001
# Finished step 1039 of 10001
# Finished step 1040 of 10001
# Finished step 1041 of 10001
# Finished step 1042 of 10001
# Finished step 1043 of 10001
# Finished step 1044 of 10001
# Finished step 1045 of 10001
# Finished step 1046 of 10001
# Finished step 1047 of 10001
# Finished step 1048 of 10001
# Finished step 1049 of 10001
# Finished step 1050 of 10001
# Finished step 1051 of 10001
# Finished step 1052 of 10001
# Finished step 1053 of 10001
# Finished step 1054 of 10001
# Finished step 1055 of 10001
# Finished step 1056 of 10001
# Finished step 1057 of 10001
# Finished step 1058 of 10001
# Finished step 1059 of 10001
# Finished step 1060 of 10001
# Finished step 1061 of 10001
# Finished step 1062 of 10001
# Finished step 1063 of 10001
# Finished step 1064 of 10001
# Finished step 1065 of 10001
# Finished step 1066 of 10001
# Finished step 1067 of 10001
# Finished step 1068 of 10001
# Finished step 1069 of 10001
# Finished step 1070 of 10001
# Finished step 1071 of 10001
# Finished step 1072 of 10001
# Finished step 1073 of 10001
# Finished step 1074 of 10001
# Finished step 1075 of 10001
# Finished step 1076 of 10001
# Finished step 1077 of 10001
# Finished step 1078 of 10001
# Finished step 1079 of 10001
# Finished step 1080 of 10001
# Finished step 1081 of 10001
# Finished step 1082 of 10001
# Finished step 1083 of 10001
# Finished step 1084 of 10001
# Finished step 1085 of 10001
# Finished step 1086 of 10001
# Finished step 1087 of 10001
# Finished step 1088 of 10001
# Finished step 1089 of 10001
# Finished step 1090 of 10001
# Finished step 1091 of 10001
# Finished step 1092 of 10001
# Finished step 1093 of 10001
# Finished step 1094 of 10001
# Finished step 1095 of 10001
# Finished step 1096 of 10001
# Finished step 1097 of 10001
# Finished step 1098 of 10001
# Finished step 1099 of 10001
# Finished step 1100 of 10001
# Finished step 1101 of 10001
# Finished step 1102 of 10001
# Finished step 1103 of 10001
# Finished step 1104 of 10001
# Finished step 1105 of 10001
# Finished step 1106 of 10001
# Finished step 1107 of 10001
# Finished step 1108 of 10001
# Finished step 1109 of 10001
# Finished step 1110 of 10001
# Finished step 1111 of 10001
# Finished step 1112 of 10001
# Finished step 1113 of 10001
# Finished step 1114 of 10001
# Finished step 1115 of 10001
# Finished step 1116 of 10001
# Finished step 1117 of 10001
# Finished step 1118 of 10001
# Finished step 1119 of 10001
# Finished step 1120 of 10001
# Finished step 1121 of 10001
# Finished step 1122 of 10001
# Finished step 1123 of 10001
# Finished step 1124 of 10001
# Finished step 1125 of 10001
# Finished step 1126 of 10001
# Finished step 1127 of 10001
# Finished step 1128 of 10001
# Finished step 1129 of 10001
# Finished step 1130 of 10001
# Finished step 1131 of 10001
# Finished step 1132 of 10001
# Finished step 1133 of 10001
# Finished step 1134 of 10001
# Finished step 1135 of 10001
# Finished step 1136 of 10001
# Finished step 1137 of 10001
# Finished step 1138 of 10001
# Finished step 1139 of 10001
# Finished step 1140 of 10001
# Finished step 1141 of 10001
# Finished step 1142 of 10001
# Finished step 1143 of 10001
# Finished step 1144 of 10001
# Finished step 1145 of 10001
# Finished step 1146 of 10001
# Finished step 1147 of 10001
# Finished step 1148 of 10001
# Finished step 1149 of 10001
# Finished step 1150 of 10001
# Finished step 1151 of 10001
# Finished step 1152 of 10001
# Finished step 1153 of 10001
# Finished step 1154 of 10001
# Finished step 1155 of 10001
# Finished step 1156 of 10001
# Finished step 1157 of 10001
# Finished step 1158 of 10001
# Finished step 1159 of 10001
# Finished step 1160 of 10001
# Finished step 1161 of 10001
# Finished step 1162 of 10001
# Finished step 1163 of 10001
# Finished step 1164 of 10001
# Finished step 1165 of 10001
# Finished step 1166 of 10001
# Finished step 1167 of 10001
# Finished step 1168 of 10001
# Finished step 1169 of 10001
# Finished step 1170 of 10001
# Finished step 1171 of 10001
# Finished step 1172 of 10001
# Finished step 1173 of 10001
# Finished step 1174 of 10001
# Finished step 1175 of 10001
# Finished step 1176 of 10001
# Finished step 1177 of 10001
# Finished step 1178 of 10001
# Finished step 1179 of 10001
# Finished step 1180 of 10001
# Finished step 1181 of 10001
# Finished step 1182 of 10001
# Finished step 1183 of 10001
# Finished step 1184 of 10001
# Finished step 1185 of 10001
# Finished step 1186 of 10001
# Finished step 1187 of 10001
# Finished step 1188 of 10001
# Finished step 1189 of 10001
# Finished step 1190 of 10001
# Finished step 1191 of 10001
# Finished step 1192 of 10001
# Finished step 1193 of 10001
# Finished step 1194 of 10001
# Finished step 1195 of 10001
# Finished step 1196 of 10001
# Finished step 1197 of 10001
# Finished step 1198 of 10001
# Finished step 1199 of 10001
# Finished step 1200 of 10001
# Finished step 1201 of 10001
# Finished step 1202 of 10001
# Finished step 1203 of 10001
# Finished step 1204 of 10001
# Finished step 1205 of 10001
# Finished step 1206 of 10001
# Finished step 1207 of 10001
# Finished step 1208 of 10001
# Finished step 1209 of 10001
# Finished step 1210 of 10001
# Finished step 1211 of 10001
# Finished step 1212 of 10001
# Finished step 1213 of 10001
# Finished step 1214 of 10001
# Finished step 1215 of 10001
# Finished step 1216 of 10001
# Finished step 1217 of 10001
# Finished step 1218 of 10001
# Finished step 1219 of 10001
# Finished step 1220 of 10001
# Finished step 1221 of 10001
# Finished step 1222 of 10001
# Finished step 1223 of 10001
# Finished step 1224 of 10001
# Finished step 1225 of 10001
# Finished step 1226 of 10001
# Finished step 1227 of 10001
# Finished step 1228 of 10001
# Finished step 1229 of 10001
# Finished step 1230 of 10001
# Finished step 1231 of 10001
# Finished step 1232 of 10001
# Finished step 1233 of 10001
# Finished step 1234 of 10001
# Finished step 1235 of 10001
# Finished step 1236 of 10001
# Finished step 1237 of 10001
# Finished step 1238 of 10001
# Finished step 1239 of 10001
# Finished step 1240 of 10001
# Finished step 1241 of 10001
# Finished step 1242 of 10001
# Finished step 1243 of 10001
# Finished step 1244 of 10001
# Finished step 1245 of 10001
# Finished step 1246 of 10001
# Finished step 1247 of 10001
# Finished step 1248 of 10001
# Finished step 1249 of 10001
# Finished step 1250 of 10001
# Finished step 1251 of 10001
# Finished step 1252 of 10001
# Finished step 1253 of 10001
# Finished step 1254 of 10001
# Finished step 1255 of 10001
# Finished step 1256 of 10001
# Finished step 1257 of 10001
# Finished step 1258 of 10001
# Finished step 1259 of 10001
# Finished step 1260 of 10001
# Finished step 1261 of 10001
# Finished step 1262 of 10001
# Finished step 1263 of 10001
# Finished step 1264 of 10001
# Finished step 1265 of 10001
# Finished step 1266 of 10001
# Finished step 1267 of 10001
# Finished step 1268 of 10001
# Finished step 1269 of 10001
# Finished step 1270 of 10001
# Finished step 1271 of 10001
# Finished step 1272 of 10001
# Finished step 1273 of 10001
# Finished step 1274 of 10001
# Finished step 1275 of 10001
# Finished step 1276 of 10001
# Finished step 1277 of 10001
# Finished step 1278 of 10001
# Finished step 1279 of 10001
# Finished step 1280 of 10001
# Finished step 1281 of 10001
# Finished step 1282 of 10001
# Finished step 1283 of 10001
# Finished step 1284 of 10001
# Finished step 1285 of 10001
# Finished step 1286 of 10001
# Finished step 1287 of 10001
# Finished step 1288 of 10001
# Finished step 1289 of 10001
# Finished step 1290 of 10001
# Finished step 1291 of 10001
# Finished step 1292 of 10001
# Finished step 1293 of 10001
# Finished step 1294 of 10001
# Finished step 1295 of 10001
# Finished step 1296 of 10001
# Finished step 1297 of 10001
# Finished step 1298 of 10001
# Finished step 1299 of 10001
# Finished step 1300 of 10001
# Finished step 1301 of 10001
# Finished step 1302 of 10001
# Finished step 1303 of 10001
# Finished step 1304 of 10001
# Finished step 1305 of 10001
# Finished step 1306 of 10001
# Finished step 1307 of 10001
# Finished step 1308 of 10001
# Finished step 1309 of 10001
# Finished step 1310 of 10001
# Finished step 1311 of 10001
# Finished step 1312 of 10001
# Finished step 1313 of 10001
# Finished step 1314 of 10001
# Finished step 1315 of 10001
# Finished step 1316 of 10001
# Finished step 1317 of 10001
# Finished step 1318 of 10001
# Finished step 1319 of 10001
# Finished step 1320 of 10001
# Finished step 1321 of 10001
# Finished step 1322 of 10001
# Finished step 1323 of 10001
# Finished step 1324 of 10001
# Finished step 1325 of 10001
# Finished step 1326 of 10001
# Finished step 1327 of 10001
# Finished step 1328 of 10001
# Finished step 1329 of 10001
# Finished step 1330 of 10001
# Finished step 1331 of 10001
# Finished step 1332 of 10001
# Finished step 1333 of 10001
# Finished step 1334 of 10001
# Finished step 1335 of 10001
# Finished step 1336 of 10001
# Finished step 1337 of 10001
# Finished step 1338 of 10001
# Finished step 1339 of 10001
# Finished step 1340 of 10001
# Finished step 1341 of 10001
# Finished step 1342 of 10001
# Finished step 1343 of 10001
# Finished step 1344 of 10001
# Finished step 1345 of 10001
# Finished step 1346 of 10001
# Finished step 1347 of 10001
# Finished step 1348 of 10001
# Finished step 1349 of 10001
# Finished step 1350 of 10001
# Finished step 1351 of 10001
# Finished step 1352 of 10001
# Finished step 1353 of 10001
# Finished step 1354 of 10001
# Finished step 1355 of 10001
# Finished step 1356 of 10001
# Finished step 1357 of 10001
# Finished step 1358 of 10001
# Finished step 1359 of 10001
# Finished step 1360 of 10001
# Finished step 1361 of 10001
# Finished step 1362 of 10001
# Finished step 1363 of 10001
# Finished step 1364 of 10001
# Finished step 1365 of 10001
# Finished step 1366 of 10001
# Finished step 1367 of 10001
# Finished step 1368 of 10001
# Finished step 1369 of 10001
# Finished step 1370 of 10001
# Finished step 1371 of 10001
# Finished step 1372 of 10001
# Finished step 1373 of 10001
# Finished step 1374 of 10001
# Finished step 1375 of 10001
# Finished step 1376 of 10001
# Finished step 1377 of 10001
# Finished step 1378 of 10001
# Finished step 1379 of 10001
# Finished step 1380 of 10001
# Finished step 1381 of 10001
# Finished step 1382 of 10001
# Finished step 1383 of 10001
# Finished step 1384 of 10001
# Finished step 1385 of 10001
# Finished step 1386 of 10001
# Finished step 1387 of 10001
# Finished step 1388 of 10001
# Finished step 1389 of 10001
# Finished step 1390 of 10001
# Finished step 1391 of 10001
# Finished step 1392 of 10001
# Finished step 1393 of 10001
# Finished step 1394 of 10001
# Finished step 1395 of 10001
# Finished step 1396 of 10001
# Finished step 1397 of 10001
# Finished step 1398 of 10001
# Finished step 1399 of 10001
# Finished step 1400 of 10001
# Finished step 1401 of 10001
# Finished step 1402 of 10001
# Finished step 1403 of 10001
# Finished step 1404 of 10001
# Finished step 1405 of 10001
# Finished step 1406 of 10001
# Finished step 1407 of 10001
# Finished step 1408 of 10001
# Finished step 1409 of 10001
# Finished step 1410 of 10001
# Finished step 1411 of 10001
# Finished step 1412 of 10001
# Finished step 1413 of 10001
# Finished step 1414 of 10001
# Finished step 1415 of 10001
# Finished step 1416 of 10001
# Finished step 1417 of 10001
# Finished step 1418 of 10001
# Finished step 1419 of 10001
# Finished step 1420 of 10001
# Finished step 1421 of 10001
# Finished step 1422 of 10001
# Finished step 1423 of 10001
# Finished step 1424 of 10001
# Finished step 1425 of 10001
# Finished step 1426 of 10001
# Finished step 1427 of 10001
# Finished step 1428 of 10001
# Finished step 1429 of 10001
# Finished step 1430 of 10001
# Finished step 1431 of 10001
# Finished step 1432 of 10001
# Finished step 1433 of 10001
# Finished step 1434 of 10001
# Finished step 1435 of 10001
# Finished step 1436 of 10001
# Finished step 1437 of 10001
# Finished step 1438 of 10001
# Finished step 1439 of 10001
# Finished step 1440 of 10001
# Finished step 1441 of 10001
# Finished step 1442 of 10001
# Finished step 1443 of 10001
# Finished step 1444 of 10001
# Finished step 1445 of 10001
# Finished step 1446 of 10001
# Finished step 1447 of 10001
# Finished step 1448 of 10001
# Finished step 1449 of 10001
# Finished step 1450 of 10001
# Finished step 1451 of 10001
# Finished step 1452 of 10001
# Finished step 1453 of 10001
# Finished step 1454 of 10001
# Finished step 1455 of 10001
# Finished step 1456 of 10001
# Finished step 1457 of 10001
# Finished step 1458 of 10001
# Finished step 1459 of 10001
# Finished step 1460 of 10001
# Finished step 1461 of 10001
# Finished step 1462 of 10001
# Finished step 1463 of 10001
# Finished step 1464 of 10001
# Finished step 1465 of 10001
# Finished step 1466 of 10001
# Finished step 1467 of 10001
# Finished step 1468 of 10001
# Finished step 1469 of 10001
# Finished step 1470 of 10001
# Finished step 1471 of 10001
# Finished step 1472 of 10001
# Finished step 1473 of 10001
# Finished step 1474 of 10001
# Finished step 1475 of 10001
# Finished step 1476 of 10001
# Finished step 1477 of 10001
# Finished step 1478 of 10001
# Finished step 1479 of 10001
# Finished step 1480 of 10001
# Finished step 1481 of 10001
# Finished step 1482 of 10001
# Finished step 1483 of 10001
# Finished step 1484 of 10001
# Finished step 1485 of 10001
# Finished step 1486 of 10001
# Finished step 1487 of 10001
# Finished step 1488 of 10001
# Finished step 1489 of 10001
# Finished step 1490 of 10001
# Finished step 1491 of 10001
# Finished step 1492 of 10001
# Finished step 1493 of 10001
# Finished step 1494 of 10001
# Finished step 1495 of 10001
# Finished step 1496 of 10001
# Finished step 1497 of 10001
# Finished step 1498 of 10001
# Finished step 1499 of 10001
# Finished step 1500 of 10001
# Finished step 1501 of 10001
# Finished step 1502 of 10001
# Finished step 1503 of 10001
# Finished step 1504 of 10001
# Finished step 1505 of 10001
# Finished step 1506 of 10001
# Finished step 1507 of 10001
# Finished step 1508 of 10001
# Finished step 1509 of 10001
# Finished step 1510 of 10001
# Finished step 1511 of 10001
# Finished step 1512 of 10001
# Finished step 1513 of 10001
# Finished step 1514 of 10001
# Finished step 1515 of 10001
# Finished step 1516 of 10001
# Finished step 1517 of 10001
# Finished step 1518 of 10001
# Finished step 1519 of 10001
# Finished step 1520 of 10001
# Finished step 1521 of 10001
# Finished step 1522 of 10001
# Finished step 1523 of 10001
# Finished step 1524 of 10001
# Finished step 1525 of 10001
# Finished step 1526 of 10001
# Finished step 1527 of 10001
# Finished step 1528 of 10001
# Finished step 1529 of 10001
# Finished step 1530 of 10001
# Finished step 1531 of 10001
# Finished step 1532 of 10001
# Finished step 1533 of 10001
# Finished step 1534 of 10001
# Finished step 1535 of 10001
# Finished step 1536 of 10001
# Finished step 1537 of 10001
# Finished step 1538 of 10001
# Finished step 1539 of 10001
# Finished step 1540 of 10001
# Finished step 1541 of 10001
# Finished step 1542 of 10001
# Finished step 1543 of 10001
# Finished step 1544 of 10001
# Finished step 1545 of 10001
# Finished step 1546 of 10001
# Finished step 1547 of 10001
# Finished step 1548 of 10001
# Finished step 1549 of 10001
# Finished step 1550 of 10001
# Finished step 1551 of 10001
# Finished step 1552 of 10001
# Finished step 1553 of 10001
# Finished step 1554 of 10001
# Finished step 1555 of 10001
# Finished step 1556 of 10001
# Finished step 1557 of 10001
# Finished step 1558 of 10001
# Finished step 1559 of 10001
# Finished step 1560 of 10001
# Finished step 1561 of 10001
# Finished step 1562 of 10001
# Finished step 1563 of 10001
# Finished step 1564 of 10001
# Finished step 1565 of 10001
# Finished step 1566 of 10001
# Finished step 1567 of 10001
# Finished step 1568 of 10001
# Finished step 1569 of 10001
# Finished step 1570 of 10001
# Finished step 1571 of 10001
# Finished step 1572 of 10001
# Finished step 1573 of 10001
# Finished step 1574 of 10001
# Finished step 1575 of 10001
# Finished step 1576 of 10001
# Finished step 1577 of 10001
# Finished step 1578 of 10001
# Finished step 1579 of 10001
# Finished step 1580 of 10001
# Finished step 1581 of 10001
# Finished step 1582 of 10001
# Finished step 1583 of 10001
# Finished step 1584 of 10001
# Finished step 1585 of 10001
# Finished step 1586 of 10001
# Finished step 1587 of 10001
# Finished step 1588 of 10001
# Finished step 1589 of 10001
# Finished step 1590 of 10001
# Finished step 1591 of 10001
# Finished step 1592 of 10001
# Finished step 1593 of 10001
# Finished step 1594 of 10001
# Finished step 1595 of 10001
# Finished step 1596 of 10001
# Finished step 1597 of 10001
# Finished step 1598 of 10001
# Finished step 1599 of 10001
# Finished step 1600 of 10001
# Finished step 1601 of 10001
# Finished step 1602 of 10001
# Finished step 1603 of 10001
# Finished step 1604 of 10001
# Finished step 1605 of 10001
# Finished step 1606 of 10001
# Finished step 1607 of 10001
# Finished step 1608 of 10001
# Finished step 1609 of 10001
# Finished step 1610 of 10001
# Finished step 1611 of 10001
# Finished step 1612 of 10001
# Finished step 1613 of 10001
# Finished step 1614 of 10001
# Finished step 1615 of 10001
# Finished step 1616 of 10001
# Finished step 1617 of 10001
# Finished step 1618 of 10001
# Finished step 1619 of 10001
# Finished step 1620 of 10001
# Finished step 1621 of 10001
# Finished step 1622 of 10001
# Finished step 1623 of 10001
# Finished step 1624 of 10001
# Finished step 1625 of 10001
# Finished step 1626 of 10001
# Finished step 1627 of 10001
# Finished step 1628 of 10001
# Finished step 1629 of 10001
# Finished step 1630 of 10001
# Finished step 1631 of 10001
# Finished step 1632 of 10001
# Finished step 1633 of 10001
# Finished step 1634 of 10001
# Finished step 1635 of 10001
# Finished step 1636 of 10001
# Finished step 1637 of 10001
# Finished step 1638 of 10001
# Finished step 1639 of 10001
# Finished step 1640 of 10001
# Finished step 1641 of 10001
# Finished step 1642 of 10001
# Finished step 1643 of 10001
# Finished step 1644 of 10001
# Finished step 1645 of 10001
# Finished step 1646 of 10001
# Finished step 1647 of 10001
# Finished step 1648 of 10001
# Finished step 1649 of 10001
# Finished step 1650 of 10001
# Finished step 1651 of 10001
# Finished step 1652 of 10001
# Finished step 1653 of 10001
# Finished step 1654 of 10001
# Finished step 1655 of 10001
# Finished step 1656 of 10001
# Finished step 1657 of 10001
# Finished step 1658 of 10001
# Finished step 1659 of 10001
# Finished step 1660 of 10001
# Finished step 1661 of 10001
# Finished step 1662 of 10001
# Finished step 1663 of 10001
# Finished step 1664 of 10001
# Finished step 1665 of 10001
# Finished step 1666 of 10001
# Finished step 1667 of 10001
# Finished step 1668 of 10001
# Finished step 1669 of 10001
# Finished step 1670 of 10001
# Finished step 1671 of 10001
# Finished step 1672 of 10001
# Finished step 1673 of 10001
# Finished step 1674 of 10001
# Finished step 1675 of 10001
# Finished step 1676 of 10001
# Finished step 1677 of 10001
# Finished step 1678 of 10001
# Finished step 1679 of 10001
# Finished step 1680 of 10001
# Finished step 1681 of 10001
# Finished step 1682 of 10001
# Finished step 1683 of 10001
# Finished step 1684 of 10001
# Finished step 1685 of 10001
# Finished step 1686 of 10001
# Finished step 1687 of 10001
# Finished step 1688 of 10001
# Finished step 1689 of 10001
# Finished step 1690 of 10001
# Finished step 1691 of 10001
# Finished step 1692 of 10001
# Finished step 1693 of 10001
# Finished step 1694 of 10001
# Finished step 1695 of 10001
# Finished step 1696 of 10001
# Finished step 1697 of 10001
# Finished step 1698 of 10001
# Finished step 1699 of 10001
# Finished step 1700 of 10001
# Finished step 1701 of 10001
# Finished step 1702 of 10001
# Finished step 1703 of 10001
# Finished step 1704 of 10001
# Finished step 1705 of 10001
# Finished step 1706 of 10001
# Finished step 1707 of 10001
# Finished step 1708 of 10001
# Finished step 1709 of 10001
# Finished step 1710 of 10001
# Finished step 1711 of 10001
# Finished step 1712 of 10001
# Finished step 1713 of 10001
# Finished step 1714 of 10001
# Finished step 1715 of 10001
# Finished step 1716 of 10001
# Finished step 1717 of 10001
# Finished step 1718 of 10001
# Finished step 1719 of 10001
# Finished step 1720 of 10001
# Finished step 1721 of 10001
# Finished step 1722 of 10001
# Finished step 1723 of 10001
# Finished step 1724 of 10001
# Finished step 1725 of 10001
# Finished step 1726 of 10001
# Finished step 1727 of 10001
# Finished step 1728 of 10001
# Finished step 1729 of 10001
# Finished step 1730 of 10001
# Finished step 1731 of 10001
# Finished step 1732 of 10001
# Finished step 1733 of 10001
# Finished step 1734 of 10001
# Finished step 1735 of 10001
# Finished step 1736 of 10001
# Finished step 1737 of 10001
# Finished step 1738 of 10001
# Finished step 1739 of 10001
# Finished step 1740 of 10001
# Finished step 1741 of 10001
# Finished step 1742 of 10001
# Finished step 1743 of 10001
# Finished step 1744 of 10001
# Finished step 1745 of 10001
# Finished step 1746 of 10001
# Finished step 1747 of 10001
# Finished step 1748 of 10001
# Finished step 1749 of 10001
# Finished step 1750 of 10001
# Finished step 1751 of 10001
# Finished step 1752 of 10001
# Finished step 1753 of 10001
# ...
# Finished step 9431 of 10001
# Finished step 9432 of 10001
# Finished step 9433 of 10001
# Finished step 9434 of 10001
# Finished step 9435 of 10001
# Finished step 9436 of 10001
# Finished step 9437 of 10001
# Finished step 9438 of 10001
# Finished step 9439 of 10001
# Finished step 9440 of 10001
# Finished step 9441 of 10001
# Finished step 9442 of 10001
# Finished step 9443 of 10001
# Finished step 9444 of 10001
# Finished step 9445 of 10001
# Finished step 9446 of 10001
# Finished step 9447 of 10001
# Finished step 9448 of 10001
# Finished step 9449 of 10001
# Finished step 9450 of 10001
# Finished step 9451 of 10001
# Finished step 9452 of 10001
# Finished step 9453 of 10001
# Finished step 9454 of 10001
# Finished step 9455 of 10001
# Finished step 9456 of 10001
# Finished step 9457 of 10001
# Finished step 9458 of 10001
# Finished step 9459 of 10001
# Finished step 9460 of 10001
# Finished step 9461 of 10001
# Finished step 9462 of 10001
# Finished step 9463 of 10001
# Finished step 9464 of 10001
# Finished step 9465 of 10001
# Finished step 9466 of 10001
# Finished step 9467 of 10001
# Finished step 9468 of 10001
# Finished step 9469 of 10001
# Finished step 9470 of 10001
# Finished step 9471 of 10001
# Finished step 9472 of 10001
# Finished step 9473 of 10001
# Finished step 9474 of 10001
# Finished step 9475 of 10001
# Finished step 9476 of 10001
# Finished step 9477 of 10001
# Finished step 9478 of 10001
# Finished step 9479 of 10001
# Finished step 9480 of 10001
# Finished step 9481 of 10001
# Finished step 9482 of 10001
# Finished step 9483 of 10001
# Finished step 9484 of 10001
# Finished step 9485 of 10001
# Finished step 9486 of 10001
# Finished step 9487 of 10001
# Finished step 9488 of 10001
# Finished step 9489 of 10001
# Finished step 9490 of 10001
# Finished step 9491 of 10001
# Finished step 9492 of 10001
# Finished step 9493 of 10001
# Finished step 9494 of 10001
# Finished step 9495 of 10001
# Finished step 9496 of 10001
# Finished step 9497 of 10001
# Finished step 9498 of 10001
# Finished step 9499 of 10001
# Finished step 9500 of 10001
# Finished step 9501 of 10001
# Finished step 9502 of 10001
# Finished step 9503 of 10001
# Finished step 9504 of 10001
# Finished step 9505 of 10001
# Finished step 9506 of 10001
# Finished step 9507 of 10001
# Finished step 9508 of 10001
# Finished step 9509 of 10001
# Finished step 9510 of 10001
# Finished step 9511 of 10001
# Finished step 9512 of 10001
# Finished step 9513 of 10001
# Finished step 9514 of 10001
# Finished step 9515 of 10001
# Finished step 9516 of 10001
# Finished step 9517 of 10001
# Finished step 9518 of 10001
# Finished step 9519 of 10001
# Finished step 9520 of 10001
# Finished step 9521 of 10001
# Finished step 9522 of 10001
# Finished step 9523 of 10001
# Finished step 9524 of 10001
# Finished step 9525 of 10001
# Finished step 9526 of 10001
# Finished step 9527 of 10001
# Finished step 9528 of 10001
# Finished step 9529 of 10001
# Finished step 9530 of 10001
# Finished step 9531 of 10001
# Finished step 9532 of 10001
# Finished step 9533 of 10001
# Finished step 9534 of 10001
# Finished step 9535 of 10001
# Finished step 9536 of 10001
# Finished step 9537 of 10001
# Finished step 9538 of 10001
# Finished step 9539 of 10001
# Finished step 9540 of 10001
# Finished step 9541 of 10001
# Finished step 9542 of 10001
# Finished step 9543 of 10001
# Finished step 9544 of 10001
# Finished step 9545 of 10001
# Finished step 9546 of 10001
# Finished step 9547 of 10001
# Finished step 9548 of 10001
# Finished step 9549 of 10001
# Finished step 9550 of 10001
# Finished step 9551 of 10001
# Finished step 9552 of 10001
# Finished step 9553 of 10001
# Finished step 9554 of 10001
# Finished step 9555 of 10001
# Finished step 9556 of 10001
# Finished step 9557 of 10001
# Finished step 9558 of 10001
# Finished step 9559 of 10001
# Finished step 9560 of 10001
# Finished step 9561 of 10001
# Finished step 9562 of 10001
# Finished step 9563 of 10001
# Finished step 9564 of 10001
# Finished step 9565 of 10001
# Finished step 9566 of 10001
# Finished step 9567 of 10001
# Finished step 9568 of 10001
# Finished step 9569 of 10001
# Finished step 9570 of 10001
# Finished step 9571 of 10001
# Finished step 9572 of 10001
# Finished step 9573 of 10001
# Finished step 9574 of 10001
# Finished step 9575 of 10001
# Finished step 9576 of 10001
# Finished step 9577 of 10001
# Finished step 9578 of 10001
# Finished step 9579 of 10001
# Finished step 9580 of 10001
# Finished step 9581 of 10001
# Finished step 9582 of 10001
# Finished step 9583 of 10001
# Finished step 9584 of 10001
# Finished step 9585 of 10001
# Finished step 9586 of 10001
# Finished step 9587 of 10001
# Finished step 9588 of 10001
# Finished step 9589 of 10001
# Finished step 9590 of 10001
# Finished step 9591 of 10001
# Finished step 9592 of 10001
# Finished step 9593 of 10001
# Finished step 9594 of 10001
# Finished step 9595 of 10001
# Finished step 9596 of 10001
# Finished step 9597 of 10001
# Finished step 9598 of 10001
# Finished step 9599 of 10001
# Finished step 9600 of 10001
# Finished step 9601 of 10001
# Finished step 9602 of 10001
# Finished step 9603 of 10001
# Finished step 9604 of 10001
# Finished step 9605 of 10001
# Finished step 9606 of 10001
# Finished step 9607 of 10001
# Finished step 9608 of 10001
# Finished step 9609 of 10001
# Finished step 9610 of 10001
# Finished step 9611 of 10001
# Finished step 9612 of 10001
# Finished step 9613 of 10001
# Finished step 9614 of 10001
# Finished step 9615 of 10001
# Finished step 9616 of 10001
# Finished step 9617 of 10001
# Finished step 9618 of 10001
# Finished step 9619 of 10001
# Finished step 9620 of 10001
# Finished step 9621 of 10001
# Finished step 9622 of 10001
# Finished step 9623 of 10001
# Finished step 9624 of 10001
# Finished step 9625 of 10001
# Finished step 9626 of 10001
# Finished step 9627 of 10001
# Finished step 9628 of 10001
# Finished step 9629 of 10001
# Finished step 9630 of 10001
# Finished step 9631 of 10001
# Finished step 9632 of 10001
# Finished step 9633 of 10001
# Finished step 9634 of 10001
# Finished step 9635 of 10001
# Finished step 9636 of 10001
# Finished step 9637 of 10001
# Finished step 9638 of 10001
# Finished step 9639 of 10001
# Finished step 9640 of 10001
# Finished step 9641 of 10001
# Finished step 9642 of 10001
# Finished step 9643 of 10001
# Finished step 9644 of 10001
# Finished step 9645 of 10001
# Finished step 9646 of 10001
# Finished step 9647 of 10001
# Finished step 9648 of 10001
# Finished step 9649 of 10001
# Finished step 9650 of 10001
# Finished step 9651 of 10001
# Finished step 9652 of 10001
# Finished step 9653 of 10001
# Finished step 9654 of 10001
# Finished step 9655 of 10001
# Finished step 9656 of 10001
# Finished step 9657 of 10001
# Finished step 9658 of 10001
# Finished step 9659 of 10001
# Finished step 9660 of 10001
# Finished step 9661 of 10001
# Finished step 9662 of 10001
# Finished step 9663 of 10001
# Finished step 9664 of 10001
# Finished step 9665 of 10001
# Finished step 9666 of 10001
# Finished step 9667 of 10001
# Finished step 9668 of 10001
# Finished step 9669 of 10001
# Finished step 9670 of 10001
# Finished step 9671 of 10001
# Finished step 9672 of 10001
# Finished step 9673 of 10001
# Finished step 9674 of 10001
# Finished step 9675 of 10001
# Finished step 9676 of 10001
# Finished step 9677 of 10001
# Finished step 9678 of 10001
# Finished step 9679 of 10001
# Finished step 9680 of 10001
# Finished step 9681 of 10001
# Finished step 9682 of 10001
# Finished step 9683 of 10001
# Finished step 9684 of 10001
# Finished step 9685 of 10001
# Finished step 9686 of 10001
# Finished step 9687 of 10001
# Finished step 9688 of 10001
# Finished step 9689 of 10001
# Finished step 9690 of 10001
# Finished step 9691 of 10001
# Finished step 9692 of 10001
# Finished step 9693 of 10001
# Finished step 9694 of 10001
# Finished step 9695 of 10001
# Finished step 9696 of 10001
# Finished step 9697 of 10001
# Finished step 9698 of 10001
# Finished step 9699 of 10001
# Finished step 9700 of 10001
# Finished step 9701 of 10001
# Finished step 9702 of 10001
# Finished step 9703 of 10001
# Finished step 9704 of 10001
# Finished step 9705 of 10001
# Finished step 9706 of 10001
# Finished step 9707 of 10001
# Finished step 9708 of 10001
# Finished step 9709 of 10001
# Finished step 9710 of 10001
# Finished step 9711 of 10001
# Finished step 9712 of 10001
# Finished step 9713 of 10001
# Finished step 9714 of 10001
# Finished step 9715 of 10001
# Finished step 9716 of 10001
# Finished step 9717 of 10001
# Finished step 9718 of 10001
# Finished step 9719 of 10001
# Finished step 9720 of 10001
# Finished step 9721 of 10001
# Finished step 9722 of 10001
# Finished step 9723 of 10001
# Finished step 9724 of 10001
# Finished step 9725 of 10001
# Finished step 9726 of 10001
# Finished step 9727 of 10001
# Finished step 9728 of 10001
# Finished step 9729 of 10001
# Finished step 9730 of 10001
# Finished step 9731 of 10001
# Finished step 9732 of 10001
# Finished step 9733 of 10001
# Finished step 9734 of 10001
# Finished step 9735 of 10001
# Finished step 9736 of 10001
# Finished step 9737 of 10001
# Finished step 9738 of 10001
# Finished step 9739 of 10001
# Finished step 9740 of 10001
# Finished step 9741 of 10001
# Finished step 9742 of 10001
# Finished step 9743 of 10001
# Finished step 9744 of 10001
# Finished step 9745 of 10001
# Finished step 9746 of 10001
# Finished step 9747 of 10001
# Finished step 9748 of 10001
# Finished step 9749 of 10001
# Finished step 9750 of 10001
# Finished step 9751 of 10001
# Finished step 9752 of 10001
# Finished step 9753 of 10001
# Finished step 9754 of 10001
# Finished step 9755 of 10001
# Finished step 9756 of 10001
# Finished step 9757 of 10001
# Finished step 9758 of 10001
# Finished step 9759 of 10001
# Finished step 9760 of 10001
# Finished step 9761 of 10001
# Finished step 9762 of 10001
# Finished step 9763 of 10001
# Finished step 9764 of 10001
# Finished step 9765 of 10001
# Finished step 9766 of 10001
# Finished step 9767 of 10001
# Finished step 9768 of 10001
# Finished step 9769 of 10001
# Finished step 9770 of 10001
# Finished step 9771 of 10001
# Finished step 9772 of 10001
# Finished step 9773 of 10001
# Finished step 9774 of 10001
# Finished step 9775 of 10001
# Finished step 9776 of 10001
# Finished step 9777 of 10001
# Finished step 9778 of 10001
# Finished step 9779 of 10001
# Finished step 9780 of 10001
# Finished step 9781 of 10001
# Finished step 9782 of 10001
# Finished step 9783 of 10001
# Finished step 9784 of 10001
# Finished step 9785 of 10001
# Finished step 9786 of 10001
# Finished step 9787 of 10001
# Finished step 9788 of 10001
# Finished step 9789 of 10001
# Finished step 9790 of 10001
# Finished step 9791 of 10001
# Finished step 9792 of 10001
# Finished step 9793 of 10001
# Finished step 9794 of 10001
# Finished step 9795 of 10001
# Finished step 9796 of 10001
# Finished step 9797 of 10001
# Finished step 9798 of 10001
# Finished step 9799 of 10001
# Finished step 9800 of 10001
# Finished step 9801 of 10001
# Finished step 9802 of 10001
# Finished step 9803 of 10001
# Finished step 9804 of 10001
# Finished step 9805 of 10001
# Finished step 9806 of 10001
# Finished step 9807 of 10001
# Finished step 9808 of 10001
# Finished step 9809 of 10001
# Finished step 9810 of 10001
# Finished step 9811 of 10001
# Finished step 9812 of 10001
# Finished step 9813 of 10001
# Finished step 9814 of 10001
# Finished step 9815 of 10001
# Finished step 9816 of 10001
# Finished step 9817 of 10001
# Finished step 9818 of 10001
# Finished step 9819 of 10001
# Finished step 9820 of 10001
# Finished step 9821 of 10001
# Finished step 9822 of 10001
# Finished step 9823 of 10001
# Finished step 9824 of 10001
# Finished step 9825 of 10001
# Finished step 9826 of 10001
# Finished step 9827 of 10001
# Finished step 9828 of 10001
# Finished step 9829 of 10001
# Finished step 9830 of 10001
# Finished step 9831 of 10001
# Finished step 9832 of 10001
# Finished step 9833 of 10001
# Finished step 9834 of 10001
# Finished step 9835 of 10001
# Finished step 9836 of 10001
# Finished step 9837 of 10001
# Finished step 9838 of 10001
# Finished step 9839 of 10001
# Finished step 9840 of 10001
# Finished step 9841 of 10001
# Finished step 9842 of 10001
# Finished step 9843 of 10001
# Finished step 9844 of 10001
# Finished step 9845 of 10001
# Finished step 9846 of 10001
# Finished step 9847 of 10001
# Finished step 9848 of 10001
# Finished step 9849 of 10001
# Finished step 9850 of 10001
# Finished step 9851 of 10001
# Finished step 9852 of 10001
# Finished step 9853 of 10001
# Finished step 9854 of 10001
# Finished step 9855 of 10001
# Finished step 9856 of 10001
# Finished step 9857 of 10001
# Finished step 9858 of 10001
# Finished step 9859 of 10001
# Finished step 9860 of 10001
# Finished step 9861 of 10001
# Finished step 9862 of 10001
# Finished step 9863 of 10001
# Finished step 9864 of 10001
# Finished step 9865 of 10001
# Finished step 9866 of 10001
# Finished step 9867 of 10001
# Finished step 9868 of 10001
# Finished step 9869 of 10001
# Finished step 9870 of 10001
# Finished step 9871 of 10001
# Finished step 9872 of 10001
# Finished step 9873 of 10001
# Finished step 9874 of 10001
# Finished step 9875 of 10001
# Finished step 9876 of 10001
# Finished step 9877 of 10001
# Finished step 9878 of 10001
# Finished step 9879 of 10001
# Finished step 9880 of 10001
# Finished step 9881 of 10001
# Finished step 9882 of 10001
# Finished step 9883 of 10001
# Finished step 9884 of 10001
# Finished step 9885 of 10001
# Finished step 9886 of 10001
# Finished step 9887 of 10001
# Finished step 9888 of 10001
# Finished step 9889 of 10001
# Finished step 9890 of 10001
# Finished step 9891 of 10001
# Finished step 9892 of 10001
# Finished step 9893 of 10001
# Finished step 9894 of 10001
# Finished step 9895 of 10001
# Finished step 9896 of 10001
# Finished step 9897 of 10001
# Finished step 9898 of 10001
# Finished step 9899 of 10001
# Finished step 9900 of 10001
# Finished step 9901 of 10001
# Finished step 9902 of 10001
# Finished step 9903 of 10001
# Finished step 9904 of 10001
# Finished step 9905 of 10001
# Finished step 9906 of 10001
# Finished step 9907 of 10001
# Finished step 9908 of 10001
# Finished step 9909 of 10001
# Finished step 9910 of 10001
# Finished step 9911 of 10001
# Finished step 9912 of 10001
# Finished step 9913 of 10001
# Finished step 9914 of 10001
# Finished step 9915 of 10001
# Finished step 9916 of 10001
# Finished step 9917 of 10001
# Finished step 9918 of 10001
# Finished step 9919 of 10001
# Finished step 9920 of 10001
# Finished step 9921 of 10001
# Finished step 9922 of 10001
# Finished step 9923 of 10001
# Finished step 9924 of 10001
# Finished step 9925 of 10001
# Finished step 9926 of 10001
# Finished step 9927 of 10001
# Finished step 9928 of 10001
# Finished step 9929 of 10001
# Finished step 9930 of 10001
# Finished step 9931 of 10001
# Finished step 9932 of 10001
# Finished step 9933 of 10001
# Finished step 9934 of 10001
# Finished step 9935 of 10001
# Finished step 9936 of 10001
# Finished step 9937 of 10001
# Finished step 9938 of 10001
# Finished step 9939 of 10001
# Finished step 9940 of 10001
# Finished step 9941 of 10001
# Finished step 9942 of 10001
# Finished step 9943 of 10001
# Finished step 9944 of 10001
# Finished step 9945 of 10001
# Finished step 9946 of 10001
# Finished step 9947 of 10001
# Finished step 9948 of 10001
# Finished step 9949 of 10001
# Finished step 9950 of 10001
# Finished step 9951 of 10001
# Finished step 9952 of 10001
# Finished step 9953 of 10001
# Finished step 9954 of 10001
# Finished step 9955 of 10001
# Finished step 9956 of 10001
# Finished step 9957 of 10001
# Finished step 9958 of 10001
# Finished step 9959 of 10001
# Finished step 9960 of 10001
# Finished step 9961 of 10001
# Finished step 9962 of 10001
# Finished step 9963 of 10001
# Finished step 9964 of 10001
# Finished step 9965 of 10001
# Finished step 9966 of 10001
# Finished step 9967 of 10001
# Finished step 9968 of 10001
# Finished step 9969 of 10001
# Finished step 9970 of 10001
# Finished step 9971 of 10001
# Finished step 9972 of 10001
# Finished step 9973 of 10001
# Finished step 9974 of 10001
# Finished step 9975 of 10001
# Finished step 9976 of 10001
# Finished step 9977 of 10001
# Finished step 9978 of 10001
# Finished step 9979 of 10001
# Finished step 9980 of 10001
# Finished step 9981 of 10001
# Finished step 9982 of 10001
# Finished step 9983 of 10001
# Finished step 9984 of 10001
# Finished step 9985 of 10001
# Finished step 9986 of 10001
# Finished step 9987 of 10001
# Finished step 9988 of 10001
# Finished step 9989 of 10001
# Finished step 9990 of 10001
# Finished step 9991 of 10001
# Finished step 9992 of 10001
# Finished step 9993 of 10001
# Finished step 9994 of 10001
# Finished step 9995 of 10001
# Finished step 9996 of 10001
# Finished step 9997 of 10001
# Finished step 9998 of 10001
# Finished step 9999 of 10001
# Finished step 10000 of 10001
# Finished step 10001 of 10001

# %%
# With DF 

# Read in Orbit of M33 relative to M31 that we computed using LeapFrog 
M33Orbit = np.loadtxt("M33AnalyticOrbit_withDF.txt", dtype=orbit_type)

#Determine the magnitude of the position and velocities of 
# the galaxies at each point in the orbit
M31_M33_R, M31_M33_V = vector_mag(M33Orbit)

# %%
# No DF 

# Read in Orbit of M33 relative to M31 Old, from Homework 7
M33Orbit_Hmwk7 = np.loadtxt("M33AnalyticOrbit_Hmwk7.txt", dtype=orbit_type)

#Determine the magnitude of the position and velocities of 
# of MW and M31 : Homework 7 
M31_M33_R_Hmwk7, M31_M33_V_Hmwk7 = vector_mag(M33Orbit_Hmwk7)

# %%
# Actual Simulation

# Read in simulation Orbit from Homework 6
M33SimOrbit = np.genfromtxt('Orbit_M33.txt', dtype = orbit_type)
M31SimOrbit = np.genfromtxt('Orbit_M31.txt', dtype = orbit_type)

#Determine the magnitude of the position and velocities of 
# the galaxies at each point in the orbit
M31_M33_SimR, M31_M33_SimV = relative_mag(M31SimOrbit, M33SimOrbit)

# %%
# Plot the orbital separations of the galaxies 
#################################

fig, ax= plt.subplots(figsize=(12, 10))

# Plot the analytical separation of M31 and M33 from Homework 7
ax.plot(M33Orbit_Hmwk7['t'], M31_M33_R_Hmwk7, 'b', lw=5, linestyle=":", label='M31-M33 No DF')

# Plot the simulated separation of M31 and M33
ax.plot(M33SimOrbit['t'], M31_M33_SimR, 'r', lw=5, label='M31-M33 Simulation')

#### Plot the newly computed orbit with DF



# Add axis labels
ax.set_xlabel('Time (Gyr)', fontsize=22)
ax.set_ylabel('Separation (kpc)', fontsize=22)
ax.set_title("Separations vs. Time", fontsize=22)

#adjust tick label font size
ax.xaxis.set_tick_params(labelsize=22)
ax.yaxis.set_tick_params(labelsize=22)

# add a legend with some customizations.
legend = ax.legend(loc='upper left',fontsize=20)

# tight layout
fig.tight_layout()

# Save to a file
fig.savefig('orbit_M33_R_withDF.png')

# %%
# Plot the orbital velocities of the galaxies 
#################################

fig, ax= plt.subplots(figsize=(12, 10))

# Plot the analytical velocities of M31 and M33
ax.plot(M33Orbit_Hmwk7['t'], M31_M33_V_Hmwk7, 'b', lw=5, label='M31-M33 No DF')

# Plot the simulated velocities of M31 and M33
ax.plot(M33SimOrbit['t'], M31_M33_SimV, 'r', lw=5, label='M31-M33 Simulation')

###### Plot the new orbit with DF 


# Add axis labels
ax.set_xlabel('Time (Gyr)', fontsize=22)
ax.set_ylabel('Velocity (km/s)', fontsize=22)
ax.set_title("Velocities vs. Time", fontsize=22)

#adjust tick label font size
ax.xaxis.set_tick_params(labelsize=22)
ax.yaxis.set_tick_params(labelsize=22)

# add a legend with some customizations.
legend = ax.legend(loc='upper left',fontsize=20)

# tight layout
fig.tight_layout()

# Save to a file
fig.savefig('orbit_M33_V_withDF.png')

# %% [markdown]
# # 6. What other reasons might there be for why the orbits don't match?
